# %% [markdown]
# <a href="https://www.kaggle.com/code/ibrahimnibrahim/coca-cola-stocks-mae-0-1-for-test?scriptVersionId=244284578" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-01-31.csv
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-02-18.csv
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-02-24.csv
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-03-02.csv
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-03-15.csv
# /kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-02-07.csv

# %%
#helper functions:

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1)
    
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))
    dataset = dataset.shuffle(shuffle_buffer)
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache().prefetch(1)
    return dataset

def plot_series(x, y, format="-", start=0, end=None, 
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(15, 10))
    
    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)


    plt.title(title)
    plt.grid(True)
    plt.show()

def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Add an axis for the feature dimension of RNN layers
    series = tf.expand_dims(series, axis=-1)
    
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    dataset = dataset.batch(batch_size).prefetch(1)
    forecast = model.predict(dataset, verbose=0)
    
    return forecast

# %%
data_dir='/kaggle/input/coca-cola-complete-stocks-dataweekly-updated/KO_1919-09-06_2025-01-31.csv'
df=pd.read_csv(data_dir)
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1962-01-02  0.263021  0.270182  0.263021  0.263021   0.046381   806400
# 1  1962-01-03  0.259115  0.259115  0.253255  0.257161   0.045348  1574400
# 2  1962-01-04  0.257813  0.261068  0.257813  0.259115   0.045692   844800
# 3  1962-01-05  0.259115  0.262370  0.252604  0.253255   0.044659  1420800
# 4  1962-01-08  0.251302  0.251302  0.245768  0.250651   0.044200  2035200

# %%
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import StandardScaler

dataset = df["Close"]
dataset = pd.DataFrame(dataset)


scaler = StandardScaler()
scaled_data = scaler.fit_transform(dataset)

train_set, test_set = train_test_split(scaled_data, test_size=0.2, shuffle=False)

# %%
time_step=np.arange(0,len(train_set))
# train_set is a numpy array, access it using numerical index 
close=train_set[:,0] # Access all rows and the first (and only) column
valid_x=np.arange(len(train_set),len(train_set)+len(test_set))
# test_set is also a numpy array
valid_y=test_set[:,0] # Access all rows and the first (and only) column


all_close=np.concatenate((close,valid_y))
all_time=np.concatenate((time_step,valid_x))

(test_set.shape,train_set.shape)
# Out:
# ((3176, 1), (12701, 1))

# %%
import matplotlib.pyplot as plt

plot_series(time_step,close, xlabel='train_time', ylabel='train_close')
plot_series(valid_x,valid_y, xlabel='test_time', ylabel='test_close')

# %%
import tensorflow as tf

# Parameters
window_size = 10
batch_size = 16
shuffle_buffer_size = 5000

# Generate the dataset windows
train_set = windowed_dataset(close, window_size, batch_size, shuffle_buffer_size)
test_set = windowed_dataset(valid_y, window_size, batch_size, shuffle_buffer_size)

# %%
# Build the Model
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      # padding='causal'
                          ),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100)
])

 # Print the model summary 
model.summary()
init_weights = model.get_weights()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 8, 64)               │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 8, 128)              │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │           6,450 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │           1,020 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lambda (Lambda)                      │ (None, 1)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 172,611 (674.26 KB)
#  Trainable params: 172,611 (674.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))


optimizer = tf.keras.optimizers.SGD(momentum=0.9)
loss=tf.keras.losses.Huber()


model.compile(loss=loss, optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.1586 - learning_rate: 1.0000e-08
# Epoch 2/100
#  28/794 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0017
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0588 - learning_rate: 1.1220e-08
# Epoch 3/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0472 - learning_rate: 1.2589e-08
# Epoch 4/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0374 - learning_rate: 1.4125e-08
# Epoch 5/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0314 - learning_rate: 1.5849e-08
# Epoch 6/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0275 - learning_rate: 1.7783e-08
# Epoch 7/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0244 - learning_rate: 1.9953e-08
# Epoch 8/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0215 - learning_rate: 2.2387e-08
# Epoch 9/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0189 - learning_rate: 2.5119e-08
# Epoch 10/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0164 - learning_rate: 2.8184e-08
# Epoch 11/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0141 - learning_rate: 3.1623e-08
# Epoch 12/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0118 - learning_rate: 3.5481e-08
# Epoch 13/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0096 - learning_rate: 3.9811e-08
# Epoch 14/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0076 - learning_rate: 4.4668e-08
# Epoch 15/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0060 - learning_rate: 5.0119e-08
# Epoch 16/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0047 - learning_rate: 5.6234e-08
# Epoch 17/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0036 - learning_rate: 6.3096e-08
# Epoch 18/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0027 - learning_rate: 7.0795e-08
# Epoch 19/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0022 - learning_rate: 7.9433e-08
# Epoch 20/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0018 - learning_rate: 8.9125e-08
# Epoch 21/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0015 - learning_rate: 1.0000e-07
# Epoch 22/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0012 - learning_rate: 1.1220e-07
# Epoch 23/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0010 - learning_rate: 1.2589e-07
# Epoch 24/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 8.4373e-04 - learning_rate: 1.4125e-07
# Epoch 25/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 6.9481e-04 - learning_rate: 1.5849e-07
# Epoch 26/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 5.6828e-04 - learning_rate: 1.7783e-07
# Epoch 27/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 4.6197e-04 - learning_rate: 1.9953e-07
# Epoch 28/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.7484e-04 - learning_rate: 2.2387e-07
# Epoch 29/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.0480e-04 - learning_rate: 2.5119e-07
# Epoch 30/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.5079e-04 - learning_rate: 2.8184e-07
# Epoch 31/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.1043e-04 - learning_rate: 3.1623e-07
# Epoch 32/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.8165e-04 - learning_rate: 3.5481e-07
# Epoch 33/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.6220e-04 - learning_rate: 3.9811e-07
# Epoch 34/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.4916e-04 - learning_rate: 4.4668e-07
# Epoch 35/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.4066e-04 - learning_rate: 5.0119e-07
# Epoch 36/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.3483e-04 - learning_rate: 5.6234e-07
# Epoch 37/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.3013e-04 - learning_rate: 6.3096e-07
# Epoch 38/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.2579e-04 - learning_rate: 7.0795e-07
# Epoch 39/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.2192e-04 - learning_rate: 7.9433e-07
# Epoch 40/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1858e-04 - learning_rate: 8.9125e-07
# Epoch 41/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1571e-04 - learning_rate: 1.0000e-06
# Epoch 42/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1311e-04 - learning_rate: 1.1220e-06
# Epoch 43/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1090e-04 - learning_rate: 1.2589e-06
# Epoch 44/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0897e-04 - learning_rate: 1.4125e-06
# Epoch 45/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0720e-04 - learning_rate: 1.5849e-06
# Epoch 46/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0553e-04 - learning_rate: 1.7783e-06
# Epoch 47/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0394e-04 - learning_rate: 1.9953e-06
# Epoch 48/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0250e-04 - learning_rate: 2.2387e-06
# Epoch 49/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0121e-04 - learning_rate: 2.5119e-06
# Epoch 50/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0009e-04 - learning_rate: 2.8184e-06
# Epoch 51/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.9090e-05 - learning_rate: 3.1623e-06
# Epoch 52/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.8211e-05 - learning_rate: 3.5481e-06
# Epoch 53/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.7469e-05 - learning_rate: 3.9811e-06
# Epoch 54/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6904e-05 - learning_rate: 4.4668e-06
# Epoch 55/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6454e-05 - learning_rate: 5.0119e-06
# Epoch 56/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6101e-05 - learning_rate: 5.6234e-06
# Epoch 57/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.5947e-05 - learning_rate: 6.3096e-06
# Epoch 58/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6134e-05 - learning_rate: 7.0795e-06
# Epoch 59/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6364e-05 - learning_rate: 7.9433e-06
# Epoch 60/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6431e-05 - learning_rate: 8.9125e-06
# Epoch 61/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.6951e-05 - learning_rate: 1.0000e-05
# Epoch 62/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.8113e-05 - learning_rate: 1.1220e-05
# Epoch 63/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 9.9738e-05 - learning_rate: 1.2589e-05
# Epoch 64/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0226e-04 - learning_rate: 1.4125e-05
# Epoch 65/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0611e-04 - learning_rate: 1.5849e-05
# Epoch 66/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0810e-04 - learning_rate: 1.7783e-05
# Epoch 67/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0583e-04 - learning_rate: 1.9953e-05
# Epoch 68/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0548e-04 - learning_rate: 2.2387e-05
# Epoch 69/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.0927e-04 - learning_rate: 2.5119e-05
# Epoch 70/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1366e-04 - learning_rate: 2.8184e-05
# Epoch 71/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1320e-04 - learning_rate: 3.1623e-05
# Epoch 72/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.1272e-04 - learning_rate: 3.5481e-05
# Epoch 73/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.2079e-04 - learning_rate: 3.9811e-05
# Epoch 74/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.2951e-04 - learning_rate: 4.4668e-05
# Epoch 75/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.3100e-04 - learning_rate: 5.0119e-05
# Epoch 76/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.2980e-04 - learning_rate: 5.6234e-05
# Epoch 77/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.4554e-04 - learning_rate: 6.3096e-05
# Epoch 78/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.8314e-04 - learning_rate: 7.0795e-05
# Epoch 79/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.9116e-04 - learning_rate: 7.9433e-05
# Epoch 80/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.5321e-04 - learning_rate: 8.9125e-05
# Epoch 81/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.7166e-04 - learning_rate: 1.0000e-04
# Epoch 82/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 4.1150e-04 - learning_rate: 1.1220e-04
# Epoch 83/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 4.2377e-04 - learning_rate: 1.2589e-04
# Epoch 84/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 4.3747e-04 - learning_rate: 1.4125e-04
# Epoch 85/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 7.4367e-04 - learning_rate: 1.5849e-04
# Epoch 86/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 7.7880e-04 - learning_rate: 1.7783e-04
# Epoch 87/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0022 - learning_rate: 1.9953e-04
# Epoch 88/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0057 - learning_rate: 2.2387e-04
# Epoch 89/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0035 - learning_rate: 2.5119e-04
# Epoch 90/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0270 - learning_rate: 2.8184e-04
# Epoch 91/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0777 - learning_rate: 3.1623e-04
# Epoch 92/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.1432 - learning_rate: 3.5481e-04
# Epoch 93/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.6962 - learning_rate: 3.9811e-04
# Epoch 94/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.6534 - learning_rate: 4.4668e-04
# Epoch 95/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 6.7258 - learning_rate: 5.0119e-04
# Epoch 96/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.6471 - learning_rate: 5.6234e-04
# Epoch 97/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.8098 - learning_rate: 6.3096e-04
# Epoch 98/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.2147 - learning_rate: 7.0795e-04
# Epoch 99/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 3.6669 - learning_rate: 7.9433e-04
# Epoch 100/100
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 4.1764 - learning_rate: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(15, 10))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 0.001])
# Out:
# (1e-08, 0.001, 0.0, 0.001)

# %%
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# Set the learning rate
learning_rate = 8e-4

# Set the optimizer 
# if you want to use SGD i studed the learning rate TOP
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["mae"])

# %%
history = model.fit(train_set,epochs=5)
# Out:
# Epoch 1/5
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0573 - mae: 0.1185
# Epoch 2/5
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0040 - mae: 0.0413
# Epoch 3/5
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 5.5048e-04 - mae: 0.0197
# Epoch 4/5
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 9.8834e-04 - mae: 0.0260
# Epoch 5/5
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 3.4305e-04 - mae: 0.0166

# %%
# Reduce the original series
forecast_series = close

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()
plot_series(time_step[window_size-1:],(close[window_size-1:],results), xlabel='Time', ylabel='Value')

mae_all=tf.keras.metrics.mae(close[window_size-1:], results).numpy()

# %%
# Reduce the original series
forecast_series = valid_y

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()
plot_series(valid_x[window_size-1:],(valid_y[window_size-1:],results), xlabel='Time', ylabel='Value')

mae_test=tf.keras.metrics.mae(valid_y[window_size-1:], results).numpy()

# %%
print(f'MAE for all the dataset: {mae_all}')
print(f'MAE for the validation dataset: {mae_test}')
# Out:
# MAE for all the dataset: 0.015030640177428722
# MAE for the validation dataset: 0.09508481621742249
